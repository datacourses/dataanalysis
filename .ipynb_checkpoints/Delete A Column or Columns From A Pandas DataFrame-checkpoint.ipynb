# %%
import pandas as pd
file_name = "https://people.sc.fsu.edu/~jburkardt/data/csv/homes.csv"
df = pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df.drop('Sell', 1, inplace=True)
df.head()
# Out:
#     "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"   "Taxes"
# 0      160         28        10        5         3      60      0.28      3167
# 1      180         18         8        4         1      12      0.43      4033
# 2      132         13         6        3         1      41      0.33      1471
# 3      140         17         7        3         1      22      0.46      3204
# 4      240         25         8        4         3       5      2.05      3613

# %%
df.drop(df.columns[[2,3,4]], axis=1, inplace=True)
df.head()
# Out:
#     "List"   "Living"   "Age"   "Acres"   "Taxes"
# 0      160         28      60      0.28      3167
# 1      180         18      12      0.43      4033
# 2      132         13      41      0.33      1471
# 3      140         17      22      0.46      3204
# 4      240         25       5      2.05      3613

# %%
df.pop(' "Taxes"')
df.head()
# Out:
#     "List"   "Living"   "Age"   "Acres"
# 0      160         28      60      0.28
# 1      180         18      12      0.43
# 2      132         13      41      0.33
# 3      140         17      22      0.46
# 4      240         25       5      2.05

# %%
del df[' "Acres"']
df.head()
# Out:
#     "List"   "Living"   "Age"
# 0      160         28      60
# 1      180         18      12
# 2      132         13      41
# 3      140         17      22
# 4      240         25       5

# %%
df = df[df.columns[[0,1]]]
df.head()
# Out:
#     "List"   "Living"
# 0      160         28
# 1      180         18
# 2      132         13
# 3      140         17
# 4      240         25
