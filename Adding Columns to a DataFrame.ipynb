# %%
import pandas as pd
file_name = "https://people.sc.fsu.edu/~jburkardt/data/csv/homes.csv"
df = pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df['New'] = df[' "Beds"']/df[' "Taxes"']

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"       New
# 0      3167  0.001579
# 1      4033  0.000992
# 2      1471  0.002039
# 3      3204  0.000936
# 4      3613  0.001107

# %%
m = [i for i in df[' "Beds"']/df[' "Taxes"']]

# %%
df = df.head()

# %%
m = [i for i in df[' "Beds"']/df[' "Taxes"']]

# %%
m
# Out:
# [0.0015787811809283233,
#  0.0009918175055789735,
#  0.0020394289598912306,
#  0.0009363295880149813,
#  0.0011071132023249377]

# %%
df['New2'] = [0.0015787811809283233,
 0.00099181750557897352,
 0.0020394289598912306,
 0.00093632958801498128,
 0.0011071132023249377]

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"       New      New2
# 0      3167  0.001579  0.001579
# 1      4033  0.000992  0.000992
# 2      1471  0.002039  0.002039
# 3      3204  0.000936  0.000936
# 4      3613  0.001107  0.001107

# %%
m = [0.0015787811809283233,
 0.00099181750557897352,
 0.0020394289598912306,
 0.00093632958801498128,
 0.0011071132023249377]

# %%
len(m)
# Out:
# 5

# %%
len(df)
# Out:
# 5

# %%
df['Me'] = "text"

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"       New      New2    Me
# 0      3167  0.001579  0.001579  text
# 1      4033  0.000992  0.000992  text
# 2      1471  0.002039  0.002039  text
# 3      3204  0.000936  0.000936  text
# 4      3613  0.001107  0.001107  text

# %%
df.insert(12, "Date", [1,2,3,4,5], True)

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"       New      New2    Me  Date
# 0      3167  0.001579  0.001579  text     1
# 1      4033  0.000992  0.000992  text     2
# 2      1471  0.002039  0.002039  text     3
# 3      3204  0.000936  0.000936  text     4
# 4      3613  0.001107  0.001107  text     5

# %%
df['Large_Beds'] = df[' "Beds"'] >= 5

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"       New      New2    Me  Date  Large_Beds
# 0      3167  0.001579  0.001579  text     1        True
# 1      4033  0.000992  0.000992  text     2       False
# 2      1471  0.002039  0.002039  text     3       False
# 3      3204  0.000936  0.000936  text     4       False
# 4      3613  0.001107  0.001107  text     5       False

# %%
lb = df.groupby(["Large_Beds"])[' "Beds"'].mean()

# %%
lb
# Out:
# Large_Beds
# False    3.5
# True     5.0
# Name:  "Beds", dtype: float64

# %%
new_df = pd.merge(df,lb,on="Large_Beds")
new_df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"_x   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10          5         3      60      0.28
# 1   175      180         18         8          4         1      12      0.43
# 2   129      132         13         6          3         1      41      0.33
# 3   138      140         17         7          3         1      22      0.46
# 4   232      240         25         8          4         3       5      2.05
#
#     "Taxes"       New      New2    Me  Date Large_Beds   "Beds"_y
# 0      3167  0.001579  0.001579  text     1       True        5.0
# 1      4033  0.000992  0.000992  text     2      False        3.5
# 2      1471  0.002039  0.002039  text     3      False        3.5
# 3      3204  0.000936  0.000936  text     4      False        3.5
# 4      3613  0.001107  0.001107  text     5      False        3.5

# %%
new_df = new_df.rename(columns={'"Beds"_y':"Avg_Bed_Size"})
new_df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"_x   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10          5         3      60      0.28
# 1   175      180         18         8          4         1      12      0.43
# 2   129      132         13         6          3         1      41      0.33
# 3   138      140         17         7          3         1      22      0.46
# 4   232      240         25         8          4         3       5      2.05
#
#     "Taxes"       New      New2    Me  Date Large_Beds   "Beds"_y
# 0      3167  0.001579  0.001579  text     1       True        5.0
# 1      4033  0.000992  0.000992  text     2      False        3.5
# 2      1471  0.002039  0.002039  text     3      False        3.5
# 3      3204  0.000936  0.000936  text     4      False        3.5
# 4      3613  0.001107  0.001107  text     5      False        3.5
