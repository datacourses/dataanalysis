# %%
import pandas as pd
file_name = "https://people.sc.fsu.edu/~jburkardt/data/csv/homes.csv"
df = pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df.dtypes
# Out:
# Sell           int64
#  "List"        int64
#  "Living"      int64
#  "Rooms"       int64
#  "Beds"        int64
#  "Baths"       int64
#  "Age"         int64
#  "Acres"     float64
#  "Taxes"       int64
# dtype: object

# %%
df['Sell'] = df['Sell'].astype(float)

# %%
df.head()
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0  142.0      160         28        10        5         3      60      0.28
# 1  175.0      180         18         8        4         1      12      0.43
# 2  129.0      132         13         6        3         1      41      0.33
# 3  138.0      140         17         7        3         1      22      0.46
# 4  232.0      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df['Sell'] = pd.to_numeric(df['Sell'])
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df[df["Sell"] >= 150]
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 1    175      180         18         8        4         1      12      0.43
# 4    232      240         25         8        4         3       5      2.05
# 6    150      160         20         8        4         3      18      4.00
# 7    207      225         22         8        4         2      16      2.22
# 8    271      285         30        10        5         2      30      0.53
# 10   153      157         22         8        3         3      18      0.38
# 12   234      238         25         8        4         2       2      1.61
# 14   175      180         22         8        4         2      15      2.06
# 15   165      170         17         8        4         2      33      0.46
# 16   166      170         23         9        4         2      37      0.27
# 19   151      153         19         8        4         2      24      0.34
# ...

# %%
df[(df["Sell"] >= 150) & (df["Sell"] < 200)]
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 1    175      180         18         8        4         1      12      0.43
# 6    150      160         20         8        4         3      18      4.00
# 10   153      157         22         8        3         3      18      0.38
# 14   175      180         22         8        4         2      15      2.06
# 15   165      170         17         8        4         2      33      0.46
# 16   166      170         23         9        4         2      37      0.27
# 19   151      153         19         8        4         2      24      0.34
# 20   180      190         24         9        4         2      10      1.55
# 22   167      170         20         9        4         2      46      0.46
# 23   190      193         22         9        5         2      37      0.48
# 24   184      190         21         9        5         2      27      1.30
# ...

# %%
df.query('(Sell >= 150)')
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 1    175      180         18         8        4         1      12      0.43
# 4    232      240         25         8        4         3       5      2.05
# 6    150      160         20         8        4         3      18      4.00
# 7    207      225         22         8        4         2      16      2.22
# 8    271      285         30        10        5         2      30      0.53
# 10   153      157         22         8        3         3      18      0.38
# 12   234      238         25         8        4         2       2      1.61
# 14   175      180         22         8        4         2      15      2.06
# 15   165      170         17         8        4         2      33      0.46
# 16   166      170         23         9        4         2      37      0.27
# 19   151      153         19         8        4         2      24      0.34
# ...

# %%
df.loc[df['Sell'] >= 150]
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 1    175      180         18         8        4         1      12      0.43
# 4    232      240         25         8        4         3       5      2.05
# 6    150      160         20         8        4         3      18      4.00
# 7    207      225         22         8        4         2      16      2.22
# 8    271      285         30        10        5         2      30      0.53
# 10   153      157         22         8        3         3      18      0.38
# 12   234      238         25         8        4         2       2      1.61
# 14   175      180         22         8        4         2      15      2.06
# 15   165      170         17         8        4         2      33      0.46
# 16   166      170         23         9        4         2      37      0.27
# 19   151      153         19         8        4         2      24      0.34
# ...

# %%
df.loc[df['Sell'].isin([170,157])]
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 25   157      165         20         8        4         2       7      0.30
# 36   170      190         24        10        3         2      33      0.57
# 39   157      163         18         8        4         2      12      1.13
#
#      "Taxes"
# 25      3785
# 36      3346
# 39      3982
