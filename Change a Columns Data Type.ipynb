# %%
import pandas as pd
file_name = "https://people.sc.fsu.edu/~jburkardt/data/csv/homes.csv"
df = pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df.dtypes
# Out:
# Sell           int64
#  "List"        int64
#  "Living"      int64
#  "Rooms"       int64
#  "Beds"        int64
#  "Baths"       int64
#  "Age"         int64
#  "Acres"     float64
#  "Taxes"       int64
# dtype: object

# %%
df['Sell'] = df['Sell'].astype(float)

# %%
df.head()
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0  142.0      160         28        10        5         3      60      0.28
# 1  175.0      180         18         8        4         1      12      0.43
# 2  129.0      132         13         6        3         1      41      0.33
# 3  138.0      140         17         7        3         1      22      0.46
# 4  232.0      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df['Sell'] = pd.to_numeric(df['Sell'])
df.head()
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0  142.0      160         28        10        5         3      60      0.28
# 1  175.0      180         18         8        4         1      12      0.43
# 2  129.0      132         13         6        3         1      41      0.33
# 3  138.0      140         17         7        3         1      22      0.46
# 4  232.0      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df.head()
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0  142.0      160         28        10        5         3      60      0.28
# 1  175.0      180         18         8        4         1      12      0.43
# 2  129.0      132         13         6        3         1      41      0.33
# 3  138.0      140         17         7        3         1      22      0.46
# 4  232.0      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df[df["Sell"] >= 150]
# Out:
#      Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 1   175.0      180         18         8        4         1      12      0.43
# 4   232.0      240         25         8        4         3       5      2.05
# 6   150.0      160         20         8        4         3      18      4.00
# 7   207.0      225         22         8        4         2      16      2.22
# 8   271.0      285         30        10        5         2      30      0.53
# 10  153.0      157         22         8        3         3      18      0.38
# 12  234.0      238         25         8        4         2       2      1.61
# 14  175.0      180         22         8        4         2      15      2.06
# 15  165.0      170         17         8        4         2      33      0.46
# 16  166.0      170         23         9        4         2      37      0.27
# 19  151.0      153         19         8        4         2      24      0.34
# 20  180.0      190         24         9        4         2      10      1.55
# 21  293.0      305         26         8        4         3       6      0.46
# 22  167.0      170         20         9        4         2      46      0.46
# 23  190.0      193         22         9        5         2      37      0.48
# 24  184.0      190         21         9        5         2      27      1.30
# 25  157.0      165         20         8        4         2       7      0.30
# 28  567.0      625         64        11        4         4       4      0.85
# 29  180.0      185         20         8        4         2      11      1.00
# 30  183.0      188         17         7        3         2      16      3.00
# 31  185.0      193         20         9        3         2      56      6.49
# 32  152.0      155         17         8        4         1      33      0.70
# 34  152.0      159         15         7        3         1      25      0.59
# 36  170.0      190         24        10        3         2      33      0.57
# 38  265.0      270         36        10        6         3      33      1.20
# 39  157.0      163         18         8        4         2      12      1.13
# 43  212.0      230         39        12        5         3     202      4.29
# 47  247.0      252         29         9        4         2       4      1.25
#
#      "Taxes"
# 1       4033
# 4       3613
# 6       3131
# 7       5158
# 8       5702
# 10      4127
# 12      2087
# 14      3917
# 15      2220
# 16      3498
# 19      3561
# 20      4681
# 21      7088
# 22      3482
# 23      3920
# 24      4162
# 25      3785
# 28     12192
# 29      3831
# 30      3564
# 31      3765
# 32      3361
# 34      3055
# 36      3346
# 38      5853
# 39      3982
# 43      3648
# 47      4626

# %%
df[(df["Sell"] >= 150) & (df["Sell"] < 200)]
# Out:
#      Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 1   175.0      180         18         8        4         1      12      0.43
# 6   150.0      160         20         8        4         3      18      4.00
# 10  153.0      157         22         8        3         3      18      0.38
# 14  175.0      180         22         8        4         2      15      2.06
# 15  165.0      170         17         8        4         2      33      0.46
# 16  166.0      170         23         9        4         2      37      0.27
# 19  151.0      153         19         8        4         2      24      0.34
# 20  180.0      190         24         9        4         2      10      1.55
# 22  167.0      170         20         9        4         2      46      0.46
# 23  190.0      193         22         9        5         2      37      0.48
# 24  184.0      190         21         9        5         2      27      1.30
# 25  157.0      165         20         8        4         2       7      0.30
# 29  180.0      185         20         8        4         2      11      1.00
# 30  183.0      188         17         7        3         2      16      3.00
# 31  185.0      193         20         9        3         2      56      6.49
# 32  152.0      155         17         8        4         1      33      0.70
# 34  152.0      159         15         7        3         1      25      0.59
# 36  170.0      190         24        10        3         2      33      0.57
# 39  157.0      163         18         8        4         2      12      1.13
#
#      "Taxes"
# 1       4033
# 6       3131
# 10      4127
# 14      3917
# 15      2220
# 16      3498
# 19      3561
# 20      4681
# 22      3482
# 23      3920
# 24      4162
# 25      3785
# 29      3831
# 30      3564
# 31      3765
# 32      3361
# 34      3055
# 36      3346
# 39      3982

# %%
df.query('(Sell >= 150)').head()
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 1  175.0      180         18         8        4         1      12      0.43
# 4  232.0      240         25         8        4         3       5      2.05
# 6  150.0      160         20         8        4         3      18      4.00
# 7  207.0      225         22         8        4         2      16      2.22
# 8  271.0      285         30        10        5         2      30      0.53
#
#     "Taxes"
# 1      4033
# 4      3613
# 6      3131
# 7      5158
# 8      5702

# %%
df.loc[df['Sell'] >= 150].head()
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 1  175.0      180         18         8        4         1      12      0.43
# 4  232.0      240         25         8        4         3       5      2.05
# 6  150.0      160         20         8        4         3      18      4.00
# 7  207.0      225         22         8        4         2      16      2.22
# 8  271.0      285         30        10        5         2      30      0.53
#
#     "Taxes"
# 1      4033
# 4      3613
# 6      3131
# 7      5158
# 8      5702

# %%
df.loc[df['Sell'].isin([170,157])]
# Out:
#      Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 25  157.0      165         20         8        4         2       7      0.30
# 36  170.0      190         24        10        3         2      33      0.57
# 39  157.0      163         18         8        4         2      12      1.13
#
#      "Taxes"
# 25      3785
# 36      3346
# 39      3982

# %%
file_name = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv"
df_ts = pd.read_csv(file_name)

# %%
df_ts.dtypes
# Out:
# Date     object
# Temp    float64
# dtype: object

# %%
df_ts["Date"] = pd.to_datetime(df_ts["Date"])

# %%
df_ts.head()
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-02  17.9
# 2 1981-01-03  18.8
# 3 1981-01-04  14.6
# 4 1981-01-05  15.8

# %%
df_ts.dtypes
# Out:
# Date    datetime64[ns]
# Temp           float64
# dtype: object
