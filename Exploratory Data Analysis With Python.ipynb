# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline 
sns.set(color_codes=True)

# %%
file_name = "https://people.sc.fsu.edu/~jburkardt/data/csv/homes.csv"
df = pd.read_csv(file_name)

# %%
df.columns = ['Sell', 'List', 'Living', 'Rooms', 'Beds', 'Baths',
       'Age', 'Acres', 'Taxes']

# %%
df.head()
# Out:
#    Sell  List  Living  Rooms  Beds  Baths  Age  Acres  Taxes
# 0   142   160      28     10     5      3   60   0.28   3167
# 1   175   180      18      8     4      1   12   0.43   4033
# 2   129   132      13      6     3      1   41   0.33   1471
# 3   138   140      17      7     3      1   22   0.46   3204
# 4   232   240      25      8     4      3    5   2.05   3613

# %%
df.dtypes
# Out:
# Sell        int64
# List        int64
# Living      int64
# Rooms       int64
# Beds        int64
# Baths       int64
# Age         int64
# Acres     float64
# Taxes       int64
# dtype: object

# %%
df.count()
# Out:
# Sell      50
# List      50
# Living    50
# Rooms     50
# Beds      50
# Baths     50
# Age       50
# Acres     50
# Taxes     50
# dtype: int64

# %%
df = df.drop_duplicates()
df.count()
# Out:
# Sell      50
# List      50
# Living    50
# Rooms     50
# Beds      50
# Baths     50
# Age       50
# Acres     50
# Taxes     50
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# Sell      0
# List      0
# Living    0
# Rooms     0
# Beds      0
# Baths     0
# Age       0
# Acres     0
# Taxes     0
# dtype: int64

# %%
df.dtypes
# Out:
# Sell        int64
# List        int64
# Living      int64
# Rooms       int64
# Beds        int64
# Baths       int64
# Age         int64
# Acres     float64
# Taxes       int64
# dtype: object

# %%
df['Beds'] = df['Beds'].astype('category')

# %%
df['Rooms'] = df['Rooms'].astype('category')

# %%
df.dtypes
# Out:
# Sell         int64
# List         int64
# Living       int64
# Rooms     category
# Beds      category
# Baths        int64
# Age          int64
# Acres      float64
# Taxes        int64
# dtype: object

# %%
df.describe()
# Out:
#              Sell        List     Living      Baths         Age      Acres  \
# count   50.000000   50.000000  50.000000  50.000000   50.000000  50.000000
# mean   170.360000  178.340000  21.120000   1.860000   30.220000   1.020600
# std     72.755885   79.382723   8.351072   0.756199   30.962314   1.191496
# min     87.000000   90.000000  10.000000   1.000000    2.000000   0.220000
# 25%    135.000000  140.000000  17.000000   1.000000   12.250000   0.382500
# 50%    152.000000  160.000000  20.000000   2.000000   24.500000   0.550000
# 75%    182.250000  190.000000  22.750000   2.000000   37.000000   1.182500
# max    567.000000  625.000000  64.000000   4.000000  202.000000   6.490000
#
#               Taxes
# count     50.000000
# mean    3706.100000
# std     1579.915268
# min     1445.000000
# 25%     3107.000000
# 50%     3490.000000
# 75%     3919.250000
# max    12192.000000

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
df.corr()
# Out:
#             Sell      List    Living     Baths       Age     Acres     Taxes
# Sell    1.000000  0.997433  0.879381  0.640059 -0.147343  0.168713  0.899339
# List    0.997433  1.000000  0.891618  0.640295 -0.130325  0.166838  0.906636
# Living  0.879381  0.891618  1.000000  0.668437  0.125075  0.177488  0.810243
# Baths   0.640059  0.640295  0.668437  1.000000 -0.023063  0.301119  0.582622
# Age    -0.147343 -0.130325  0.125075 -0.023063  1.000000  0.303733 -0.189221
# Acres   0.168713  0.166838  0.177488  0.301119  0.303733  1.000000  0.059647
# Taxes   0.899339  0.906636  0.810243  0.582622 -0.189221  0.059647  1.000000

# %%
sns.set(style="ticks")
sns.pairplot(df[["Sell","Taxes","Acres","Beds"]])

# %%
sns.set(style="ticks")
sns.pairplot(df[["Sell","Taxes","Acres","Beds"]], hue="Beds")
# Out:
# /Users/andrew.owens/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/andrew.owens/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/andrew.owens/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /Users/andrew.owens/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.set(style="ticks")
sns.pairplot(df, hue="Beds")

# %%
sns.scatterplot(x="Taxes", y="Acres",data=df)

# %%
sns.scatterplot(x="Taxes", y="Sell",data=df)

# %%
df.plot.scatter(x='Taxes',y='Acres',c='Baths',colormap='viridis')

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a3428ce48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a34f7b978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3404f710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a33f064e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a33ccc160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30dd5be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a30d02ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30b6f7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a30b6f588>]],
#       dtype=object)

# %%
df['Baths'].hist()

# %%
df['Taxes'].hist()

# %%
df['Sell'].hist()

# %%
df['List'].hist()

# %%
df.boxplot(column=['List'])

# %%
df[['List','Beds']].boxplot(by='Beds')

# %%
sns.boxplot(x='Beds', y='Sell', data=df,palette='rainbow')

# %%
#Histograms and Distribution Plots
sns.distplot(df['List'])

# %%
sns.jointplot(x='List',y='Sell',data=df,kind='hex')
