# %%
import pandas as pd
import requests

# %%
dicts = {
    'Colorado' : 'Rockies',
    'Boston'   : 'Red Sox',
    'Minnesota': 'Twins',
    'Milwaukee': 'Brewers',
    'Seattle'  : 'Mariners'}

# %%
pd.DataFrame.from_dict(dicts)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-8dadf0a18bf6> in <module>()
# ----> 1 pd.DataFrame.from_dict(dicts)
#
# /Users/andrewwowens/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in from_dict(cls, data, orient, dtype, columns)
#    1136             raise ValueError('only recognize index or columns for orient')
#    1137
# -> 1138         return cls(data, index=index, columns=columns, dtype=dtype)
#    1139
#    1140     def to_numpy(self, dtype=None, copy=False):
#
# /Users/andrewwowens/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
# ...

# %%
dicts = mlb_team = {'Team':
    {'Colorado' : 'Rockies',
    'Boston'   : 'Red Sox',
    'Minnesota': 'Twins',
    'Milwaukee': 'Brewers',
    'Seattle'  : 'Mariners'}}

# %%
pd.DataFrame.from_dict(dicts)
# Out:
#                Team
# Boston      Red Sox
# Colorado    Rockies
# Milwaukee   Brewers
# Minnesota     Twins
# Seattle    Mariners

# %%
url = "https://gbfs.citibikenyc.com/gbfs/en/station_information.json"
r = requests.get(url)
type(r.json())
# Out:
# dict

# %%
r.json()['data']['stations'][0]
# Out:
# {u'capacity': 39,
#  u'eightd_has_key_dispenser': False,
#  u'eightd_station_services': [{u'bikes_availability': u'UNLIMITED',
#    u'description': u'Citi Bike Station Valet attendant service available',
#    u'docks_availability': u'UNLIMITED',
#    u'id': u'e73b6bfb-961f-432c-a61b-8e94c42a1fba',
#    u'link_for_more_info': u'https://www.citibikenyc.com/valet',
#    u'name': u'Valet Service',
#    u'schedule_description': u'',
#    u'service_type': u'ATTENDED_SERVICE'}],
#  u'electric_bike_surcharge_waiver': False,
#  u'external_id': u'66db3c29-0aca-11e7-82f6-3863bb44ef7c',
#  u'has_kiosk': True,
#  u'lat': 40.73047309,
#  u'lon': -73.98672378,
#  u'name': u'E 11 St & 2 Ave',
#  u'region_id': 71,
#  u'rental_methods': [u'CREDITCARD', u'KEY'],
#  u'rental_url': u'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=237',
#  u'short_name': u'5746.04',
#  u'station_id': u'237'}

# %%
pd.DataFrame.from_dict(r.json()['data']['stations'])
# Out:
#      capacity  eightd_has_key_dispenser  \
# 0          39                     False
# 1          66                      True
# 2          58                     False
# 3          33                      True
# 4          30                     False
# 5          37                     False
# 6          35                     False
# 7          28                     False
# 8          50                     False
# 9          64                     False
# 10         47                     False
# 11         29                      True
# 12         31                     False
# 13         27                     False
# 14         47                     False
# 15         39                     False
# 16         31                     False
# 17         34                     False
# 18         51                     False
# 19         34                     False
# 20         79                     False
# 21         52                      True
# ...

# %%
pd.DataFrame(r.json()['data']['stations'])
# Out:
#      capacity  eightd_has_key_dispenser  \
# 0          39                     False
# 1          66                      True
# 2          58                     False
# 3          33                      True
# 4          30                     False
# 5          37                     False
# 6          35                     False
# 7          28                     False
# 8          50                     False
# 9          64                     False
# 10         47                     False
# 11         29                      True
# 12         31                     False
# 13         27                     False
# 14         47                     False
# 15         39                     False
# 16         31                     False
# 17         34                     False
# 18         51                     False
# 19         34                     False
# 20         79                     False
# 21         52                      True
# ...
