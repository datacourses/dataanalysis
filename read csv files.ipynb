# %%
import pandas as pd
file_name = "https://people.sc.fsu.edu/~jburkardt/data/csv/homes.csv"

# %%
df = pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df = pd.read_csv(file_name, header=0)

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df = pd.read_csv(file_name, index_col= 0)

# %%
df.head()
# Out:
#        "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# Sell
# 142       160         28        10        5         3      60      0.28
# 175       180         18         8        4         1      12      0.43
# 129       132         13         6        3         1      41      0.33
# 138       140         17         7        3         1      22      0.46
# 232       240         25         8        4         3       5      2.05
#
#        "Taxes"
# Sell
# 142       3167
# 175       4033
# 129       1471
# 138       3204
# 232       3613

# %%
df = pd.read_csv(file_name, usecols = [0,1,2])

# %%
df.head()
# Out:
#    Sell   "List"   "Living"
# 0   142      160         28
# 1   175      180         18
# 2   129      132         13
# 3   138      140         17
# 4   232      240         25

# %%
 df = pd.read_csv(file_name, nrows=10)

# %%
df.count()
# Out:
# Sell         10
#  "List"      10
#  "Living"    10
#  "Rooms"     10
#  "Beds"      10
#  "Baths"     10
#  "Age"       10
#  "Acres"     10
#  "Taxes"     10
# dtype: int64

# %%
df = pd.read_csv(file_name, skiprows=9)

# %%
df.head()
# Out:
#    271   285   30   10   5   2    30   0.53    5702
# 0   89    90   10    5   3   1    43   0.30    2054
# 1  153   157   22    8   3   3    18   0.38    4127
# 2   87    90   16    7   3   1    50   0.65    1445
# 3  234   238   25    8   4   2     2   1.61    2087
# 4  106   116   20    8   4   1    13   0.22    2818

# %%
df = pd.read_csv(file_name, skiprows=9)

# %%
df.head()
# Out:
#    271   285   30   10   5   2    30   0.53    5702
# 0   89    90   10    5   3   1    43   0.30    2054
# 1  153   157   22    8   3   3    18   0.38    4127
# 2   87    90   16    7   3   1    50   0.65    1445
# 3  234   238   25    8   4   2     2   1.61    2087
# 4  106   116   20    8   4   1    13   0.22    2818

# %%
df = pd.read_csv(file_name, na_values={"Sell": 175})

# %%
df.head()
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0  142.0      160         28        10        5         3      60      0.28
# 1    NaN      180         18         8        4         1      12      0.43
# 2  129.0      132         13         6        3         1      41      0.33
# 3  138.0      140         17         7        3         1      22      0.46
# 4  232.0      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613

# %%
df = pd.read_csv(file_name, na_values=[1])

# %%
df.head()
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613
